# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.16.1

# %%
import numpy as np

def calculate_miou(predictions, ground_truths):
    """
    Calcola la Mean Intersection over Union (MIoU) tra predizioni e verità terreno.
    
    Parameters:
        predictions (numpy.ndarray): Array delle predizioni, shape (64, 128, C).
        ground_truths (numpy.ndarray): Array delle verità terreno, shape (64, 128, C).
        
    Returns:
        float: MIoU calcolata sulle classi.
    """
    assert predictions.shape == ground_truths.shape, "Le shape devono coincidere!"
    C = predictions.shape[-1]
    
    iou_per_class = []
    
    for c in range(C):
        # Otteniamo la maschera per la classe c
        pred_class = predictions[..., c]
        gt_class = ground_truths[..., c]
        
        # Calcoliamo intersezione e unione
        intersection = np.logical_and(pred_class, gt_class).sum()
        union = np.logical_or(pred_class, gt_class).sum()
        
        # Evitiamo divisioni per zero
        if union == 0:
            iou = 1.0  # Se non ci sono pixel in questa classe, consideriamo IOU = 1
        else:
            iou = intersection / union
        
        iou_per_class.append(iou)
    
    # Calcoliamo la media delle IoU per tutte le classi
    print(iou_per_class)
    miou = np.mean(iou_per_class)
    return miou

# %%
# !pip install tfa-nightly keras_cv Pillow
# Out:
# Requirement already satisfied: tfa-nightly in /opt/conda/lib/python3.10/site-packages (0.23.0.dev20240415222534)
# Requirement already satisfied: keras_cv in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (10.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tfa-nightly) (21.3)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /opt/conda/lib/python3.10/site-packages (from tfa-nightly) (2.13.3)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from keras_cv) (2024.5.15)
# Requirement already satisfied: tensorflow-datasets in /opt/conda/lib/python3.10/site-packages (from keras_cv) (4.9.6)
# Requirement already satisfied: keras-core in /opt/conda/lib/python3.10/site-packages (from keras_cv) (0.1.7)
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.10/site-packages (from keras_cv) (0.3.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from kagglehub->keras_cv) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from kagglehub->keras_cv) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras-core->keras_cv) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras-core->keras_cv) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras-core->keras_cv) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-core->keras_cv) (3.11.0)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.10/site-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tfa-nightly) (3.1.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (8.1.7)
# Requirement already satisfied: immutabledict in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (4.2.0)
# Requirement already satisfied: promise in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (3.20.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (5.9.3)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.14.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (2.4.0)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (1.7.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (2024.6.0)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (6.4.0)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.10/site-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras_cv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras_cv) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras_cv) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->kagglehub->keras_cv) (2024.6.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras-core->keras_cv) (2.18.0)
# Requirement already satisfied: docstring-parser~=0.15 in /opt/conda/lib/python3.10/site-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.10/site-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv) (1.63.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)

# %%
# Set batch size for training
BATCH_SIZE = 256

# Set learning rate for the optimiser
LEARNING_RATE = 1e-4

# Set early stopping patience threshold
PATIENCE = 30

# Set maximum number of training epochs
EPOCHS = 1000

NUM_CLASSES=5

# %%
import numpy as np

data = np.load("/kaggle/input/mars-dataset/mars_for_students.npz")
training_set = data["training_set"]

X_train = training_set[:, 0]
y_train = training_set[:, 1]

X_test = data["test_set"]

# %% [markdown]
# ## Data cleaning

# %%
# Get the reference label (y_train[62])
reference_label = y_train[62]

# Filter the dataset where y_train is not equal to the reference label
mask = [not np.array_equal(label, reference_label) for label in y_train]

print(f"Original dataset size: {len(X_train)}")

X_train = X_train[mask]
y_train = y_train[mask]

print(f"Filtered dataset size: {len(X_train)}")
# Out:
# Original dataset size: 2615
# Filtered dataset size: 2505

# %%
def apply_colormap(label, colormap=None):
    """
    Apply the colormap to a label.
    """
    # Ensure label is 2D
    label = np.squeeze(label)

    if colormap is None:
        num_classes = len(np.unique(label))
        colormap = plt.cm.viridis(np.linspace(0, 1, num_classes))

    # Apply the colormap
    colored = colormap[label.astype(int)]

    return colored

# %%
import numpy as np

# Parametri
label_value = 0  # Label di interesse
threshold_percentage = 40

# Itera su tutte le immagini e maschere
for i, (img_batch, lbl_batch) in enumerate(zip(X_train, y_train)):
    # Check if any pixel in the label belongs to class 4
    if np.any(lbl_batch == label_value):  # Check if class 4 is present in the label

        total_pixels = 64 * 128
        label_pixels = np.sum(lbl_batch == label_value)
        label_percentage = (label_pixels / total_pixels) * 100

        if label_percentage >= threshold_percentage:
            print(f"Img {i} contains background")

            if i < 50:
                # Plot original image
                plt.figure(figsize=(8, 4))
        
                plt.subplot(1, 2, 1)
                plt.imshow(img_batch, cmap='gray')
                plt.title("Immagine")
                plt.axis('off')
        
                # Apply the colormap to the segmentation labels
                colormap = plt.cm.viridis(np.linspace(0, 1, 5))
        
                plt.subplot(1, 2, 2)
                colored_label = apply_colormap(lbl_batch, colormap)
                plt.imshow(colored_label, cmap='viridis')
                plt.title("Label (Segmentazione)")
                plt.axis('off')
        
                plt.show()
# Out:
# Img 2 contains background
# Img 3 contains background
# Img 4 contains background
# Img 7 contains background
# Img 8 contains background
# Img 10 contains background
# Img 11 contains background
# Img 12 contains background
# Img 15 contains background
# Img 23 contains background
# Img 26 contains background
# Img 30 contains background
# Img 32 contains background
# Img 35 contains background
# Img 42 contains background
# Img 46 contains background
# Img 49 contains background
# Img 52 contains background
# Img 53 contains background
# Img 55 contains background
# Img 57 contains background
# Img 58 contains background
# Img 61 contains background
# Img 67 contains background
# Img 72 contains background
# Img 76 contains background
# Img 84 contains background
# Img 89 contains background
# Img 90 contains background
# Img 100 contains background
# Img 105 contains background
# Img 106 contains background
# Img 115 contains background
# Img 116 contains background
# Img 117 contains background
# Img 120 contains background
# Img 121 contains background
# Img 130 contains background
# Img 133 contains background
# Img 134 contains background
# Img 138 contains background
# Img 140 contains background
# Img 145 contains background
# Img 149 contains background
# Img 151 contains background
# Img 154 contains background
# Img 158 contains background
# Img 161 contains background
# Img 162 contains background
# Img 164 contains background
# Img 166 contains background
# Img 170 contains background
# Img 171 contains background
# Img 182 contains background
# Img 184 contains background
# Img 191 contains background
# Img 194 contains background
# Img 199 contains background
# Img 200 contains background
# Img 201 contains background
# Img 202 contains background
# Img 205 contains background
# Img 208 contains background
# Img 212 contains background
# Img 214 contains background
# Img 217 contains background
# Img 219 contains background
# Img 221 contains background
# Img 226 contains background
# Img 233 contains background
# Img 237 contains background
# Img 241 contains background
# Img 242 contains background
# Img 249 contains background
# Img 261 contains background
# Img 266 contains background
# Img 270 contains background
# Img 273 contains background
# Img 275 contains background
# Img 279 contains background
# Img 280 contains background
# Img 287 contains background
# Img 290 contains background
# Img 297 contains background
# Img 307 contains background
# Img 308 contains background
# Img 316 contains background
# Img 321 contains background
# Img 325 contains background
# Img 326 contains background
# Img 330 contains background
# Img 332 contains background
# Img 336 contains background
# Img 337 contains background
# Img 339 contains background
# Img 342 contains background
# Img 344 contains background
# Img 345 contains background
# Img 351 contains background
# Img 364 contains background
# Img 368 contains background
# Img 382 contains background
# Img 383 contains background
# Img 384 contains background
# Img 385 contains background
# Img 386 contains background
# Img 387 contains background
# Img 388 contains background
# Img 397 contains background
# Img 399 contains background
# Img 406 contains background
# Img 409 contains background
# Img 412 contains background
# Img 413 contains background
# Img 414 contains background
# Img 423 contains background
# Img 427 contains background
# Img 428 contains background
# Img 432 contains background
# Img 439 contains background
# Img 441 contains background
# Img 445 contains background
# Img 446 contains background
# Img 452 contains background
# Img 453 contains background
# Img 458 contains background
# Img 459 contains background
# Img 460 contains background
# Img 462 contains background
# Img 471 contains background
# Img 472 contains background
# Img 477 contains background
# Img 478 contains background
# Img 479 contains background
# Img 480 contains background
# Img 483 contains background
# Img 489 contains background
# Img 495 contains background
# Img 497 contains background
# Img 499 contains background
# Img 501 contains background
# Img 502 contains background
# Img 506 contains background
# Img 508 contains background
# Img 512 contains background
# Img 513 contains background
# Img 545 contains background
# Img 547 contains background
# Img 554 contains background
# Img 556 contains background
# Img 557 contains background
# Img 560 contains background
# Img 564 contains background
# Img 573 contains background
# Img 580 contains background
# Img 591 contains background
# Img 599 contains background
# Img 601 contains background
# Img 602 contains background
# Img 603 contains background
# Img 605 contains background
# Img 609 contains background
# Img 614 contains background
# Img 620 contains background
# Img 626 contains background
# Img 632 contains background
# Img 639 contains background
# Img 648 contains background
# Img 654 contains background
# Img 655 contains background
# Img 660 contains background
# Img 662 contains background
# Img 668 contains background
# Img 671 contains background
# Img 674 contains background
# Img 683 contains background
# Img 685 contains background
# Img 692 contains background
# Img 693 contains background
# Img 698 contains background
# Img 706 contains background
# Img 711 contains background
# Img 716 contains background
# Img 720 contains background
# Img 722 contains background
# Img 724 contains background
# Img 726 contains background
# Img 737 contains background
# Img 742 contains background
# Img 748 contains background
# Img 753 contains background
# Img 760 contains background
# Img 766 contains background
# Img 769 contains background
# Img 787 contains background
# Img 794 contains background
# Img 795 contains background
# Img 797 contains background
# Img 798 contains background
# Img 803 contains background
# Img 804 contains background
# Img 807 contains background
# Img 813 contains background
# Img 816 contains background
# Img 824 contains background
# Img 827 contains background
# Img 833 contains background
# Img 843 contains background
# Img 848 contains background
# Img 850 contains background
# Img 851 contains background
# Img 852 contains background
# Img 858 contains background
# Img 862 contains background
# Img 867 contains background
# Img 868 contains background
# Img 872 contains background
# Img 873 contains background
# Img 874 contains background
# Img 881 contains background
# Img 882 contains background
# Img 887 contains background
# Img 888 contains background
# Img 901 contains background
# Img 904 contains background
# Img 907 contains background
# Img 915 contains background
# Img 918 contains background
# Img 920 contains background
# Img 927 contains background
# Img 930 contains background
# Img 935 contains background
# Img 936 contains background
# Img 937 contains background
# Img 942 contains background
# Img 948 contains background
# Img 955 contains background
# Img 956 contains background
# Img 957 contains background
# Img 960 contains background
# Img 963 contains background
# Img 966 contains background
# Img 974 contains background
# Img 977 contains background
# Img 986 contains background
# Img 990 contains background
# Img 999 contains background
# Img 1005 contains background
# Img 1016 contains background
# Img 1020 contains background
# Img 1022 contains background
# Img 1023 contains background
# Img 1026 contains background
# Img 1028 contains background
# Img 1029 contains background
# Img 1030 contains background
# Img 1035 contains background
# Img 1037 contains background
# Img 1039 contains background
# Img 1040 contains background
# Img 1050 contains background
# Img 1054 contains background
# Img 1057 contains background
# Img 1060 contains background
# Img 1068 contains background
# Img 1069 contains background
# Img 1079 contains background
# Img 1080 contains background
# Img 1083 contains background
# Img 1084 contains background
# Img 1085 contains background
# Img 1086 contains background
# Img 1090 contains background
# Img 1097 contains background
# Img 1099 contains background
# Img 1102 contains background
# Img 1115 contains background
# Img 1121 contains background
# Img 1123 contains background
# Img 1126 contains background
# Img 1136 contains background
# Img 1141 contains background
# Img 1143 contains background
# Img 1152 contains background
# Img 1156 contains background
# Img 1161 contains background
# Img 1162 contains background
# Img 1168 contains background
# Img 1170 contains background
# Img 1171 contains background
# Img 1173 contains background
# Img 1187 contains background
# Img 1190 contains background
# Img 1193 contains background
# Img 1199 contains background
# Img 1200 contains background
# Img 1201 contains background
# Img 1204 contains background
# Img 1207 contains background
# Img 1212 contains background
# Img 1214 contains background
# Img 1216 contains background
# Img 1217 contains background
# Img 1219 contains background
# Img 1220 contains background
# Img 1221 contains background
# Img 1225 contains background
# Img 1228 contains background
# Img 1231 contains background
# Img 1233 contains background
# Img 1238 contains background
# Img 1246 contains background
# Img 1254 contains background
# Img 1257 contains background
# Img 1266 contains background
# Img 1267 contains background
# Img 1268 contains background
# Img 1281 contains background
# Img 1282 contains background
# Img 1283 contains background
# Img 1288 contains background
# Img 1293 contains background
# Img 1296 contains background
# Img 1297 contains background
# Img 1311 contains background
# Img 1316 contains background
# Img 1317 contains background
# Img 1318 contains background
# Img 1322 contains background
# Img 1326 contains background
# Img 1328 contains background
# Img 1329 contains background
# Img 1332 contains background
# Img 1336 contains background
# Img 1344 contains background
# Img 1347 contains background
# Img 1349 contains background
# Img 1355 contains background
# Img 1357 contains background
# Img 1364 contains background
# Img 1366 contains background
# Img 1371 contains background
# Img 1372 contains background
# Img 1378 contains background
# Img 1386 contains background
# Img 1396 contains background
# Img 1398 contains background
# Img 1403 contains background
# Img 1404 contains background
# Img 1410 contains background
# Img 1414 contains background
# Img 1415 contains background
# Img 1426 contains background
# Img 1427 contains background
# Img 1429 contains background
# Img 1443 contains background
# Img 1451 contains background
# Img 1456 contains background
# Img 1457 contains background
# Img 1462 contains background
# Img 1464 contains background
# Img 1466 contains background
# Img 1469 contains background
# Img 1470 contains background
# Img 1474 contains background
# Img 1479 contains background
# Img 1489 contains background
# Img 1490 contains background
# Img 1491 contains background
# Img 1494 contains background
# Img 1498 contains background
# Img 1501 contains background
# Img 1508 contains background
# Img 1510 contains background
# Img 1514 contains background
# Img 1520 contains background
# Img 1522 contains background
# Img 1527 contains background
# Img 1534 contains background
# Img 1539 contains background
# Img 1540 contains background
# Img 1544 contains background
# Img 1546 contains background
# Img 1548 contains background
# Img 1549 contains background
# Img 1557 contains background
# Img 1562 contains background
# Img 1569 contains background
# Img 1572 contains background
# Img 1576 contains background
# Img 1580 contains background
# Img 1585 contains background
# Img 1587 contains background
# Img 1590 contains background
# Img 1593 contains background
# Img 1594 contains background
# Img 1601 contains background
# Img 1603 contains background
# Img 1607 contains background
# Img 1609 contains background
# Img 1617 contains background
# Img 1618 contains background
# Img 1619 contains background
# Img 1621 contains background
# Img 1627 contains background
# Img 1629 contains background
# Img 1632 contains background
# Img 1641 contains background
# Img 1646 contains background
# Img 1647 contains background
# Img 1651 contains background
# Img 1652 contains background
# Img 1656 contains background
# Img 1660 contains background
# Img 1663 contains background
# Img 1666 contains background
# Img 1669 contains background
# Img 1673 contains background
# Img 1679 contains background
# Img 1681 contains background
# Img 1683 contains background
# Img 1685 contains background
# Img 1691 contains background
# Img 1692 contains background
# Img 1698 contains background
# Img 1702 contains background
# Img 1708 contains background
# Img 1712 contains background
# Img 1717 contains background
# Img 1718 contains background
# Img 1720 contains background
# Img 1721 contains background
# Img 1727 contains background
# Img 1739 contains background
# Img 1741 contains background
# Img 1742 contains background
# Img 1743 contains background
# Img 1746 contains background
# Img 1750 contains background
# Img 1751 contains background
# Img 1755 contains background
# Img 1756 contains background
# Img 1759 contains background
# Img 1764 contains background
# Img 1770 contains background
# Img 1777 contains background
# Img 1778 contains background
# Img 1781 contains background
# Img 1786 contains background
# Img 1787 contains background
# Img 1792 contains background
# Img 1795 contains background
# Img 1796 contains background
# Img 1808 contains background
# Img 1818 contains background
# Img 1824 contains background
# Img 1826 contains background
# Img 1832 contains background
# Img 1833 contains background
# Img 1834 contains background
# Img 1839 contains background
# Img 1841 contains background
# Img 1853 contains background
# Img 1854 contains background
# Img 1861 contains background
# Img 1865 contains background
# Img 1866 contains background
# Img 1872 contains background
# Img 1875 contains background
# Img 1883 contains background
# Img 1900 contains background
# Img 1902 contains background
# Img 1912 contains background
# Img 1913 contains background
# Img 1914 contains background
# Img 1917 contains background
# Img 1919 contains background
# Img 1922 contains background
# Img 1924 contains background
# Img 1928 contains background
# Img 1929 contains background
# Img 1934 contains background
# Img 1942 contains background
# Img 1943 contains background
# Img 1947 contains background
# Img 1951 contains background
# Img 1952 contains background
# Img 1955 contains background
# Img 1960 contains background
# Img 1961 contains background
# Img 1967 contains background
# Img 1968 contains background
# Img 1970 contains background
# Img 1977 contains background
# Img 1978 contains background
# Img 1982 contains background
# Img 1986 contains background
# Img 1990 contains background
# Img 1991 contains background
# Img 2000 contains background
# Img 2002 contains background
# Img 2003 contains background
# Img 2004 contains background
# Img 2008 contains background
# Img 2012 contains background
# Img 2014 contains background
# Img 2016 contains background
# Img 2020 contains background
# Img 2024 contains background
# Img 2029 contains background
# Img 2030 contains background
# Img 2034 contains background
# Img 2036 contains background
# Img 2037 contains background
# Img 2045 contains background
# Img 2046 contains background
# Img 2048 contains background
# Img 2050 contains background
# Img 2056 contains background
# Img 2063 contains background
# Img 2064 contains background
# Img 2065 contains background
# Img 2068 contains background
# Img 2069 contains background
# Img 2070 contains background
# Img 2071 contains background
# Img 2079 contains background
# Img 2087 contains background
# Img 2089 contains background
# Img 2091 contains background
# Img 2092 contains background
# Img 2097 contains background
# Img 2099 contains background
# Img 2106 contains background
# Img 2109 contains background
# Img 2111 contains background
# Img 2115 contains background
# Img 2117 contains background
# Img 2118 contains background
# Img 2123 contains background
# Img 2124 contains background
# Img 2138 contains background
# Img 2140 contains background
# Img 2144 contains background
# Img 2149 contains background
# Img 2157 contains background
# Img 2160 contains background
# Img 2163 contains background
# Img 2168 contains background
# Img 2171 contains background
# Img 2178 contains background
# Img 2179 contains background
# Img 2184 contains background
# Img 2185 contains background
# Img 2192 contains background
# Img 2193 contains background
# Img 2197 contains background
# Img 2198 contains background
# Img 2199 contains background
# Img 2200 contains background
# Img 2201 contains background
# Img 2209 contains background
# Img 2218 contains background
# Img 2225 contains background
# Img 2226 contains background
# Img 2227 contains background
# Img 2232 contains background
# Img 2234 contains background
# Img 2236 contains background
# Img 2245 contains background
# Img 2246 contains background
# Img 2247 contains background
# Img 2251 contains background
# Img 2253 contains background
# Img 2259 contains background
# Img 2260 contains background
# Img 2261 contains background
# Img 2265 contains background
# Img 2266 contains background
# Img 2270 contains background
# Img 2274 contains background
# Img 2276 contains background
# Img 2287 contains background
# Img 2288 contains background
# Img 2289 contains background
# Img 2301 contains background
# Img 2302 contains background
# Img 2308 contains background
# Img 2311 contains background
# Img 2313 contains background
# Img 2314 contains background
# Img 2320 contains background
# Img 2324 contains background
# Img 2329 contains background
# Img 2330 contains background
# Img 2331 contains background
# Img 2334 contains background
# Img 2337 contains background
# Img 2351 contains background
# Img 2354 contains background
# Img 2357 contains background
# Img 2358 contains background
# Img 2363 contains background
# Img 2365 contains background
# Img 2369 contains background
# Img 2370 contains background
# Img 2377 contains background
# Img 2378 contains background
# Img 2383 contains background
# Img 2392 contains background
# Img 2397 contains background
# Img 2399 contains background
# Img 2403 contains background
# Img 2406 contains background
# Img 2407 contains background
# Img 2409 contains background
# Img 2412 contains background
# Img 2413 contains background
# Img 2414 contains background
# Img 2420 contains background
# Img 2425 contains background
# Img 2432 contains background
# Img 2445 contains background
# Img 2451 contains background
# Img 2454 contains background
# Img 2455 contains background
# Img 2456 contains background
# Img 2459 contains background
# Img 2461 contains background
# Img 2465 contains background
# Img 2473 contains background
# Img 2482 contains background
# Img 2486 contains background
# Img 2487 contains background
# Img 2488 contains background
# Img 2492 contains background
# Img 2498 contains background
# Img 2501 contains background

# %%
def cleaning_background(label):
    
     # Conta il numero di pixel per ciascuna classe
    unique, counts = np.unique(label, return_counts=True)
    class_counts = dict(zip(unique, counts))
    
    # Rimuove la classe 0 dai conteggi per trovare la classe maggioritaria
    class_counts.pop(0, None)  # Ignora la classe 0
    if class_counts:
        # Trova la classe maggioritaria
        major_class = max(class_counts, key=class_counts.get)
    else:
        # Se l'unica classe presente è la 0, sostituisci con la classe 1
        major_class = 1

    major_class = 1

    # Sostituisci i pixel della classe 0 con la classe maggioritaria
    updated_label = np.where(label == 0, major_class, label)
    
    return updated_label

# %%
idx_background = [10, 11,12,15,23,26, 32,35,49,57,58,67,72,76,
                  84,90,105,106,115,116,133,140,145,149,158,162,164,166,170,182,191,194,
                  201,202,208,212,214,226,237,241,261,266,270,273,280,287,290,297,307,308,321,
                  325,326,339,342,364,368,382,385,386,388,397,399,406,414,423,427,428,
                  432,439,441,445,446,452,458,471,480,495,497,499,502,513,545,547,556,557,564,
                  560,591,601,602,605,614,626,632,654,655,660,674,683,685,692,693,698,
                  711,726,737,742,748,760,766,769,787,794,795,797,804,807,813,816,
                  824,833,843,848,850,851,867,868,872,873,874,881,882,887,888,915,918,920,
                  927,930,935,937,942,948,955,956,957,960,990,999,1022,1023,1026,1028,1030,1035,
                  1037,1040,1050,1060,1068,1079,1083,1085,1097,1099,1123,1141,1143,1156,1162,
                  1168,1173,1187,1193,1199,1200,1201,1204,1212,1219,1220,1225,1228,1231,
                  1233,1238,1246,1266,1282,1283,1311,1316,1318,1326,1332,1336,1344,1349,
                  1357,1372,1386,1403,1415,1426,1443,1456,1462,1464,1466,1469,1474,1491,1498,
                  1501,1508,1510,1514,1527,1534,1539,1540,1544,1548,1569,1572,1576,1585,
                  1587,1590,1593,1609,1617,1618,1627,1632,1646,1656,1681,1698,1702,1708,
                  1712,1751,1755,1756,1781,1786,1795,1808,1818,1824,1826,1832,1839,1841,
                  1853,1854,1866,1872,1900,1913,1917,1919,1942,1947,1952,1955,1960,1967,
                  1978,1982,1986,1990,1991,2000,2002,2003,2004,2014,2024,2029,2034,2048,
                  2050,2064,2065,2070,2071,2079,2087,2091,2106,2111,2115,2123,2124,2149,
                  2160,2163,2168,2171,2184,2185,2192,2193,2197,2199,2218,2225,2232,2234,
                  2246,2247,2253,2266,2287,2301,2308,2311,2313,2330,2331,2337,2354,2363,2365,
                  2369,2383,2399,2406,2409,2412,2414,2420,2432,2445,2451,2456,2473,2498]

print(len(idx_background))
# Out:
# 341

# %%
'''import numpy as np

# Parametri
label_value = 0  # Label di interesse
threshold_percentage = 40

# Itera su tutte le immagini e maschere
for i, (img_batch, lbl_batch) in enumerate(zip(X_train, y_train)):
    # Check if any pixel in the label belongs to class 4
    if np.any(lbl_batch == label_value):  # Check if class 4 is present in the label

        total_pixels = 64 * 128
        label_pixels = np.sum(lbl_batch == label_value)
        label_percentage = (label_pixels / total_pixels) * 100

        if (label_percentage > 0.0) and ((label_percentage <= threshold_percentage) or i in idx_background):
            new_label = cleaning_background(lbl_batch)
            print(f"Img {i} contains background")

            if i < 50:
                # Apply the colormap to the segmentation labels
                colormap = plt.cm.viridis(np.linspace(0, 1, 5))
                
                # Plot original image
                plt.figure(figsize=(8, 4))
        
                plt.subplot(1, 2, 1)
                colored_label = apply_colormap(lbl_batch, colormap)
                plt.imshow(colored_label, cmap='viridis')
                plt.title("Immagine")
                plt.axis('off')
        
        
                plt.subplot(1, 2, 2)
                colored_label = apply_colormap(new_label, colormap)
                plt.imshow(colored_label, cmap='viridis')
                plt.title("Label (Segmentazione)")
                plt.axis('off')
        
                plt.show()
            
            y_train[i] = new_label'''
# Out:
# 'import numpy as np\n\n# Parametri\nlabel_value = 0  # Label di interesse\nthreshold_percentage = 40\n\n# Itera su tutte le immagini e maschere\nfor i, (img_batch, lbl_batch) in enumerate(zip(X_train, y_train)):\n    # Check if any pixel in the label belongs to class 4\n    if np.any(lbl_batch == label_value):  # Check if class 4 is present in the label\n\n        total_pixels = 64 * 128\n        label_pixels = np.sum(lbl_batch == label_value)\n        label_percentage = (label_pixels / total_pixels) * 100\n\n        if (label_percentage > 0.0) and ((label_percentage <= threshold_percentage) or i in idx_background):\n            new_label = cleaning_background(lbl_batch)\n            print(f"Img {i} contains background")\n\n            if i < 50:\n                # Apply the colormap to the segmentation labels\n                colormap = plt.cm.viridis(np.linspace(0, 1, 5))\n                \n                # Plot original image\n                plt.figure(figsize=(8, 4))\n        \n                plt.subplot(1, 2, 1)\n                colored_label = apply_colormap(lbl_batch, colormap)\n                plt.imshow(colored_label, cmap=\'viridis\')\n                plt.title("Immagine")\n                plt.axis(\'off\')\n        \n        \n                plt.subplot(1, 2, 2)\n                colored_label = apply_colormap(new_label, colormap)\n                plt.imshow(colored_label, cmap=\'viridis\')\n                plt.title("Label (Segmentazione)")\n                plt.axis(\'off\')\n        \n                plt.show()\n            \n            y_train[i] = new_label'

# %%
'''idx_remove = [139,735,866,1174,1533,1780]

# Rimuovi gli indici da X_train e y_train
X_train = np.delete(X_train, idx_remove, axis=0)
y_train = np.delete(y_train, idx_remove, axis=0)'''
# Out:
# 'idx_remove = [139,735,866,1174,1533,1780]\n\n# Rimuovi gli indici da X_train e y_train\nX_train = np.delete(X_train, idx_remove, axis=0)\ny_train = np.delete(y_train, idx_remove, axis=0)'

# %%
# Flatten y_train to aggregate pixel counts across all images
all_pixels = np.concatenate([y.flatten() for y in y_train])

# Count the occurrences of each class
unique_classes, counts = np.unique(all_pixels, return_counts=True)

# Calculate the total number of pixels
total_pixels = all_pixels.size

# Calculate the percentage of each class
class_percentages = {cls: (count / total_pixels) * 100 for cls, count in zip(unique_classes, counts)}

# Print results
print("Class percentages:")
for cls, percentage in class_percentages.items():
    print(f"Class {cls}: {percentage:.2f}%")
# Out:
# Class percentages:
# Class 0.0: 24.31%
# Class 1.0: 33.90%
# Class 2.0: 23.28%
# Class 3.0: 18.38%
# Class 4.0: 0.13%

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=seed
)

# %%
def unet_block(input_tensor, filters, kernel_size=3, activation='relu', stack=2, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)

    # Return the transformed tensor
    return x

# %%
# Input image
'''plt.subplot(1, 3, 1)

plt.imshow(X_train[1], cmap="gray")
plt.title("Input Image")
plt.axis('off')

# Ground truth
plt.subplot(1, 3, 2)
tensor_with_channel = tf.expand_dims(X_train[1], axis=-1)
img = augmentation_layer()(tensor_with_channel)
plt.imshow(img / 255.0, cmap="gray")
plt.title("Ground Truth Mask")
plt.axis('off')

plt.tight_layout()
plt.show()
plt.close()'''
# Out:
# 'plt.subplot(1, 3, 1)\n\nplt.imshow(X_train[1], cmap="gray")\nplt.title("Input Image")\nplt.axis(\'off\')\n\n# Ground truth\nplt.subplot(1, 3, 2)\ntensor_with_channel = tf.expand_dims(X_train[1], axis=-1)\nimg = augmentation_layer()(tensor_with_channel)\nplt.imshow(img / 255.0, cmap="gray")\nplt.title("Ground Truth Mask")\nplt.axis(\'off\')\n\nplt.tight_layout()\nplt.show()\nplt.close()'

# %%
import tensorflow as tf
from tensorflow.keras import layers
import keras_cv
import tensorflow as tf
from tensorflow.keras import layers, Model

def augmentation_layer():
    return tf.keras.Sequential([
        tf.keras.layers.RandomBrightness(0.2),
        keras_cv.layers.RandomContrast([0, 255], 0.5),
        keras_cv.layers.RandomGaussianBlur(3, 2),
        tf.keras.layers.GaussianNoise(0.05)
    ])

def transformer_block(inputs, num_heads, ff_dim):
    """Transformer block for bottleneck or encoder/decoder layers."""
    # Layer Normalization
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    # Multi-Head Attention
    attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=inputs.shape[-1])(x, x)
    # Skip Connection
    x = layers.Add()([attention_output, inputs])
    # Feed Forward Network
    ffn = tf.keras.Sequential([
        layers.Dense(ff_dim, activation="relu"),
        layers.Dense(inputs.shape[-1]),
    ])
    x_ffn = ffn(x)
    # Second Skip Connection
    x = layers.Add()([x_ffn, x])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x

def adaptive_fusion(feature_1, feature_2):
    """Adaptive feature fusion using trainable gates."""
    # Trainable gates for features
    gate_1 = layers.Dense(1, activation='sigmoid')(feature_1)
    gate_2 = layers.Dense(1, activation='sigmoid')(feature_2)
    # Weighted summation
    fused = gate_1 * feature_1 + gate_2 * feature_2
    return fused

def unet_with_transformer(input_shape=(64, 128, 1), num_classes=1):
    """U-Net with transformer bottleneck and adaptive fusion."""
    inputs = layers.Input(shape=input_shape)
    inputs = augmentation_layer()(inputs)
    
    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)
    
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)
    
    # Bottleneck with Transformer Block
    bottleneck = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    bottleneck = transformer_block(bottleneck, num_heads=4, ff_dim=512)
    
    # Decoder
    u1 = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(bottleneck)
    f1 = adaptive_fusion(c2, u1)  # Fusion of skip connection and upsampled features
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(f1)
    c3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c3)
    
    u2 = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(c3)
    f2 = adaptive_fusion(c1, u2)  # Fusion of skip connection and upsampled features
    c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(f2)
    c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c4)
    
    # Output Layer
    output_layer = layers.Conv2D(NUM_CLASSES, kernel_size=1, padding='same', activation="softmax", name='output_layer')(c4)

    model = tf.keras.Model(inputs=inputs, outputs=output_layer, name='UNet_Model')

    return model

# %%
category_map = {
        0: 0,  # unlabelled
        1: 1,
        2: 2,
        3: 3,
        4: 4
}
    
def apply_category_mapping(label):
    """
    Apply category mapping to labels.
    """
    keys_tensor = tf.constant(list(category_map.keys()), dtype=tf.int32)
    vals_tensor = tf.constant(list(category_map.values()), dtype=tf.int32)
    table = tf.lookup.StaticHashTable(
        tf.lookup.KeyValueTensorInitializer(keys_tensor, vals_tensor),
        default_value=0
    )
    return table.lookup(int(label))

# %%
import tensorflow_addons as tfa
import random

    
def rotate_fn(im, label):
    angolo = random.randint(-90, 90)

    # Otteniamo le dimensioni originali dell'immagine
    altezza, larghezza = im.shape[:2]
    
    # Calcoliamo il centro dell'immagine
    centro = (larghezza // 2, altezza // 2)
    
    # Calcoliamo la matrice di rotazione
    matrice_rotazione = cv2.getRotationMatrix2D(centro,angolo, 1.0)
    
    # Aggiustiamo la matrice per mantenere la stessa dimensione dell'immagine
    matrice_rotazione[0, 2] += (larghezza / 2) - centro[0]
    matrice_rotazione[1, 2] += (altezza / 2) - centro[1]
    
    # Ruotiamo l'immagine usando la matrice di rotazione
    immagine_ruotata = cv2.warpAffine(im, matrice_rotazione, (larghezza, altezza), flags=cv2.INTER_LINEAR)
    label_ruotata = cv2.warpAffine(label, matrice_rotazione, (larghezza, altezza), flags=cv2.INTER_LINEAR)

    return immagine_ruotata, label_ruotata



def translate_fn(im, label):
    # Genera spostamenti casuali lungo gli assi x e y
    shift_x = random.randint(-30, 30)
    shift_y = random.randint(-30, 30)

    # Otteniamo le dimensioni originali dell'immagine
    altezza, larghezza = im.shape[:2]

    # Creiamo la matrice di traslazione
    matrice_traslazione = np.array([
        [1, 0, shift_x],
        [0, 1, shift_y]
    ], dtype=np.float32)

    # Applichiamo la traslazione all'immagine e alla label
    immagine_traslata = cv2.warpAffine(im, matrice_traslazione, (larghezza, altezza), flags=cv2.INTER_LINEAR)
    label_traslata = cv2.warpAffine(label, matrice_traslazione, (larghezza, altezza), flags=cv2.INTER_NEAREST)

    return immagine_traslata, label_traslata

    
def zoom_fn(image, label):
    zoom_factor = tf.random.uniform([], 0.4, 1.6)


    # Get image dimensions (using tf.shape to avoid None)
    height, width = tf.shape(image)[0], tf.shape(image)[1]
    new_height = tf.cast(tf.cast(height, tf.float32) * zoom_factor, tf.int32)
    new_width = tf.cast(tf.cast(width, tf.float32) * zoom_factor, tf.int32)

    # Resize the image and label to the new dimensions
    image = tf.image.resize(image, [new_height, new_width], method='bilinear')
    label = tf.image.resize(label, [new_height, new_width], method='nearest')  # Nearest for labels

    # Crop or pad back to the original size
    image = tf.image.resize_with_crop_or_pad(image, height, width)
    label = tf.image.resize_with_crop_or_pad(label, height, width)

    # Cast to float64 at the start to ensure consistency
    image = tf.cast(image, tf.float64)
    label = tf.cast(label, tf.int32)

    return image, label

# %%
@tf.function
def random_flip(image, label, seed=None):
    """Consistent random horizontal flip."""

    if seed is None:
        seed = np.random.randint(0, 1000000)
    flip_prob = tf.random.uniform([], seed=seed)

    
    image = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_left_right(image),
        lambda: image
    )

    label = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_left_right(label),
        lambda: label
    )
    
    return image, label
    
@tf.function
def random_flip_up_down(image, label, seed=None):
    """Consistent random vertical flip."""

    if seed is None:
        seed = np.random.randint(0, 1000000)
    flip_prob = tf.random.uniform([], seed=seed)

    
    image = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_up_down(image),
        lambda: image
    )

    label = tf.cond(
        flip_prob > 0.5,
        lambda: tf.image.flip_up_down(label),
        lambda: label
    )
    
    return image, label
    
@tf.function
def random_zoom(image, label, seed=None):

    # Random Zoom (zoom in/out by the same factor)
    zoom_prob = tf.random.uniform([], seed=seed)

    image, label = tf.cond(
        #zoom_prob > 0.5,
        zoom_prob >= 0.2,
        lambda: zoom_fn(image, label),
        lambda: (image, label)
    )

    return image, label
    
@tf.function
def random_rotate(image, label, seed=None):
    
    # Random Rotation (rotate by the same angle)
    rotation_prob = tf.random.uniform([], seed=seed)

    image, label = tf.cond(
        #rotation_prob > 0.5,
        rotation_prob >= 0.2,
        lambda: rotate_fn(image, label),
        lambda: (image, label)
    )
    
    # Cast to float64 at the start to ensure consistency
    image = tf.cast(image, tf.float64)
    
    return image, label

@tf.function
def random_translation(image, label, seed=None):
    
    # Random translation
    rotation_prob = tf.random.uniform([], seed=seed)
    shift_x = tf.random.uniform([], minval=-20, maxval=20, dtype=tf.float32, seed=seed)
    shift_y = tf.random.uniform([], minval=-20, maxval=20, dtype=tf.float32, seed=seed)

    image, label = tf.cond(
        #rotation_prob > 0.5,
        rotation_prob >= 0.2,
        lambda: translate_fn(image, label, shift_x,shift_y),
        lambda: (image, label)
    )
    
    # Cast to float64 at the start to ensure consistency
    image = tf.cast(image, tf.float64)
    
    return image, label

# %%
def make_dataset(images, labels, batch_size, shuffle=True, augment=False, seed=None):
    """
    Create a memory-efficient TensorFlow dataset.
    """
    images = tf.expand_dims(images, axis=-1)  # Ensure images have a single channel (grayscale or RGB)
    
    # One-hot encode the labels and convert to uint8
    labels = tf.cast(labels, tf.uint8)  # Convert labels to uint8
    labels = tf.keras.backend.one_hot(labels, NUM_CLASSES)  # One-hot encoding the labels
    
    # Create dataset from images and one-hot encoded labels
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=batch_size * 2, seed=seed)

    # Apply category mapping if needed (you can modify this function as necessary)
    dataset = dataset.map(
        lambda x, y: (x, apply_category_mapping(y)),  # You can define apply_category_mapping based on your needs
        num_parallel_calls=tf.data.AUTOTUNE
    )

    if augment:
        dataset2 = dataset.map(
            lambda x, y: random_flip(x, y, seed=seed),  # Define random_flip for augmentation if necessary
            num_parallel_calls=tf.data.AUTOTUNE
        )
        dataset3 = dataset.map(
            lambda x, y: random_zoom(x, y, seed=seed),  # Define random_flip for augmentation if necessary
            num_parallel_calls=tf.data.AUTOTUNE
        )
        dataset4 = dataset.map(
            lambda x, y: random_flip_up_down(x, y, seed=seed),  # Define random_flip for augmentation if necessary
            num_parallel_calls=tf.data.AUTOTUNE
        )
        '''
        dataset5 = dataset.map(
            lambda x, y: random_translation(x, y, seed=seed),  # Define random_flip for augmentation if necessary
            num_parallel_calls=tf.data.AUTOTUNE
        )'''
        
        dataset = dataset.concatenate(dataset2)
        dataset = dataset.concatenate(dataset3)
        dataset = dataset.concatenate(dataset4)

        
        # Print the shape of a single batch from the train_dataset
        '''for img_batch, lbl_batch in dataset.take(1):  # Taking the first batch
                plt.figure(figsize=(8, 4))
    
                print("Img " + str(i))
                
                # Immagine originale
                plt.subplot(1, 2, 1)
                plt.imshow(img_batch, cmap='gray' if len(img.shape) == 2 else None)
                plt.title("Immagine")
                plt.axis('off')
                
                # Label di segmentazione
        
                colormap = plt.cm.viridis(np.linspace(0, 1, 5))


                plt.subplot(1, 2, 2)
                colored_label = apply_colormap(tf.math.argmax(lbl_batch, axis=-1), colormap)

                plt.imshow(colored_label, cmap='gray' if len(label.shape) == 2 else None)
                plt.title("Label (Segmentazione)")
                plt.axis('off')
                
                plt.show()'''



    # Batch the data
    dataset = dataset.batch(batch_size, drop_remainder=False)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset

# %%
import cv2

num_samples = len(X_train)
new_X_train = np.empty((2 * num_samples, *X_train.shape[1:]), dtype=X_train.dtype)
new_y_train = np.empty((2 * num_samples, *y_train.shape[1:]), dtype=y_train.dtype)

# Copia i dati originali
new_X_train[:num_samples] = X_train
new_y_train[:num_samples] = y_train

# Applica l'augmentazione direttamente sugli array preallocati
for idx in range(num_samples):
    img, label = rotate_fn(np.copy(X_train[idx]), np.copy(y_train[idx]))
    new_X_train[num_samples + idx] = img
    new_y_train[num_samples + idx] = label

X_train = new_X_train
y_train = new_y_train

num_samples = len(X_train)
new_X_train = np.empty((2 * num_samples, *X_train.shape[1:]), dtype=X_train.dtype)
new_y_train = np.empty((2 * num_samples, *y_train.shape[1:]), dtype=y_train.dtype)

# Copia i dati originali
new_X_train[:num_samples] = X_train
new_y_train[:num_samples] = y_train

# Applica l'augmentazione direttamente sugli array preallocati
for idx in range(num_samples):
    img, label = translate_fn(np.copy(X_train[idx]), np.copy(y_train[idx]))
    new_X_train[num_samples + idx] = img
    new_y_train[num_samples + idx] = label

X_train = new_X_train
y_train = new_y_train

# %%
train_dataset = make_dataset(
    X_train, y_train,
    batch_size=BATCH_SIZE,
    shuffle=True,
    augment=True,
    seed=seed
)

val_dataset = make_dataset(
    X_val, y_val,
    batch_size=25,
    shuffle=True,
    augment=False,
    seed=seed
)

# %%
# Print the shape of a single batch from the train_dataset
for img_batch, lbl_batch in train_dataset.take(1):  # Taking the first batch
    print("Image batch shape:", img_batch.shape)
    print("Label batch shape:", lbl_batch.shape)
# Out:
# Image batch shape: (256, 64, 128, 1)
# Label batch shape: (256, 64, 128, 5)

# %%
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    #model = get_unet_model()
    #model = unet_with_complex_bottleneck()
    model = unet_with_transformer()
    #model = build_multi_res_unet((64,128,1), NUM_CLASSES)

# %%
import random

# Define custom Mean Intersection Over Union metric
class MeanIntersectionOverUnion(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, labels_to_exclude=None, name="mean_iou", dtype=None):
        super(MeanIntersectionOverUnion, self).__init__(num_classes=num_classes, name=name, dtype=dtype)
        if labels_to_exclude is None:
            labels_to_exclude = [0]  # Default to excluding label 0
        self.labels_to_exclude = labels_to_exclude

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert predictions to class labels
        y_pred = tf.math.argmax(y_pred, axis=-1)
        y_true = tf.math.argmax(y_true, axis=-1)

        # Flatten the tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])

        # Apply mask to exclude specified labels
        for label in self.labels_to_exclude:
            mask = tf.not_equal(y_true, label)
            y_true = tf.boolean_mask(y_true, mask)
            y_pred = tf.boolean_mask(y_pred, mask)

        # Update the state
        return super().update_state(y_true, y_pred, sample_weight)

# Visualization callback
class VizCallback(tf.keras.callbacks.Callback):
    def __init__(self, images, labels, frequency=5):
        super().__init__()
        self.images = images
        self.labels = labels
        self.frequency = frequency

    def apply_colormap(self, label, colormap=None):
        """
        Apply the colormap to a label.
        """
        # Ensure label is 2D
        label = np.squeeze(label)
    
        if colormap is None:
            num_classes = len(np.unique(label))
            colormap = plt.cm.viridis(np.linspace(0, 1, num_classes))
    
        # Apply the colormap
        colored = colormap[label.astype(int)]
    
        return colored

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.frequency == 0:  # Visualize only every "frequency" epochs
            idx = random.randint(0, len(self.images))
            image = self.images[idx]
            label = self.labels[idx]
            
            image = tf.expand_dims(image, 0)
            pred = self.model.predict(image, verbose=0)
            y_pred = tf.math.argmax(pred, axis=-1)
            y_pred = y_pred.numpy()

            # Create colormap
            num_classes = NUM_CLASSES
            colormap = plt.cm.viridis(np.linspace(0, 1, num_classes))

            plt.figure(figsize=(16, 4))

            # Input image
            plt.subplot(1, 3, 1)
            plt.imshow(image[0], cmap="gray")
            plt.title("Input Image")
            plt.axis('off')

            # Ground truth
            plt.subplot(1, 3, 2)
            colored_label = self.apply_colormap(label, colormap)
            plt.imshow(colored_label)
            plt.title("Ground Truth Mask")
            plt.axis('off')

            # Prediction
            plt.subplot(1, 3, 3)
            colored_pred = self.apply_colormap(y_pred[0], colormap)
            plt.imshow(colored_pred)
            plt.title("Predicted Mask")
            plt.axis('off')

            plt.tight_layout()
            plt.show()
            plt.close()

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

import tensorflow as tf
import numpy as np

total_percentage = sum(class_percentages.values())
class_weights = {cls: total_percentage / percentage for cls, percentage in class_percentages.items()}
#class_weights = {0:1,1:0,2:0,3:0,4:1}
# Convert class_weights to a tensor (use in TensorFlow/Keras)
class_weights_tensor = tf.constant([class_weights[c] for c in sorted(class_weights.keys())], dtype=tf.float32)
#class_weights_tensor /= tf.norm(class_weights_tensor)

def weighted_categorical_crossentropy(y_true, y_pred):
    """
    Weighted Categorical Cross-Entropy Loss
    """
    # Ensure y_pred is normalized (softmax)
    y_pred = tf.keras.backend.clip(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
    
    # Compute cross-entropy
    cross_entropy = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
    
    # Apply class weights
    weights = tf.reduce_sum(class_weights_tensor * y_true, axis=-1)
    weighted_cross_entropy = weights * cross_entropy
    return tf.reduce_mean(weighted_cross_entropy)

def boundary_loss(y_true, y_pred):
    # Assume y_true and y_pred have shape (n, 64, 128, 5)

    # Compute boundaries (edge detection) for y_true and y_pred
    y_true_boundary = tf.image.extract_patches(
        y_true, sizes=[1, 3, 3, 1], strides=[1, 1, 1, 1], rates=[1, 1, 1, 1], padding='SAME')
    y_pred_boundary = tf.image.extract_patches(
        y_pred, sizes=[1, 3, 3, 1], strides=[1, 1, 1, 1], rates=[1, 1, 1, 1], padding='SAME')

    # Compute the boundary loss (difference between true and predicted boundaries)
    boundary_loss = tf.reduce_mean(tf.abs(y_true_boundary - y_pred_boundary))

    return boundary_loss
    

def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    # Ensure predictions are within valid probability range
    y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
    
    # Compute cross-entropy
    cross_entropy = -y_true * tf.math.log(y_pred)
    
    # Compute the focal weight
    focal_weight = alpha * tf.pow(1 - y_pred, gamma)
    
    # Apply the focal weight to the cross-entropy
    loss = focal_weight * cross_entropy
    
    # Take the mean over all classes
    return tf.reduce_mean(tf.reduce_sum(loss, axis=-1))
    
def dice_loss(y_true, y_pred):
    """
    Dice Loss for multi-class segmentation
    """
    y_pred = tf.keras.backend.clip(y_pred, tf.keras.backend.epsilon(), 1 - tf.keras.backend.epsilon())
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = numerator / (denominator + tf.keras.backend.epsilon())
    return 1 - tf.reduce_mean(dice)
    
def weighted_dice_loss(y_true, y_pred, class_weights):
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)
    
    # Apply softmax to predictions if necessary
    y_pred = tf.nn.softmax(y_pred, axis=-1)
    
    # Smooth factor to avoid division by zero
    smooth = 1e-6
    
    # Compute Dice numerator and denominator for each class
    intersection = tf.reduce_sum(y_true * y_pred, axis=[0, 1, 2])  # Sum over spatial dimensions
    union = tf.reduce_sum(y_true, axis=[0, 1, 2]) + tf.reduce_sum(y_pred, axis=[0, 1, 2])
    
    dice_score = (2.0 * intersection + smooth) / (union + smooth)
    
    # Compute weighted Dice loss
    class_weights = tf.convert_to_tensor(class_weights, dtype=tf.float32)
    weighted_dice = class_weights * (1.0 - dice_score)  # Higher weights for more important classes
    
    # Reduce to a single scalar loss value
    loss = tf.reduce_mean(weighted_dice)
    return loss
    
def iou_loss_for_class(y_true, y_pred, target_class, smooth=1e-6):
    """
    IoU loss for a specific class.

    Args:
    - y_true: Ground truth labels, one-hot encoded.
    - y_pred: Predicted logits or probabilities, same shape as y_true.
    - target_class: Index of the target class to calculate IoU for.
    - smooth: Small value to avoid division by zero.

    Returns:
    - IoU loss for the target class.
    """
    # Extract the class-specific predictions and ground truth
    y_true_class = y_true[..., target_class]
    y_pred_class = y_pred[..., target_class]

    # Compute intersection and union
    intersection = tf.reduce_sum(y_true_class * y_pred_class)
    union = tf.reduce_sum(y_true_class) + tf.reduce_sum(y_pred_class) - intersection

    # Compute IoU
    iou = (intersection + smooth) / (union + smooth)

    # IoU loss is 1 - IoU
    return 1 - iou
    
@tf.function
def combined_loss(y_true, y_pred, lambda_=0.5):
    """
    Combined Loss: Weighted Categorical Cross-Entropy + Dice Loss
    """
    loss_ce = weighted_categorical_crossentropy(y_true, y_pred)
    loss_dice = weighted_dice_loss(y_true, y_pred, class_weights_tensor)
    loss_focal = focal_loss(y_true, y_pred)
 
    return loss_ce + loss_dice + loss_focal

# Compile the model with the custom combined loss
print("Compiling model...")
with strategy.scope():
    model.compile(
        loss=combined_loss,
        optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE),
        metrics=[MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0]),
            tf.keras.metrics.IoU(NUM_CLASSES, [1], name="class1", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [2], name="class2", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [3], name="class3", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [4], name="class4", sparse_y_true=False, sparse_y_pred=False)
        ]
    )
print("Model compiled!")
# Out:
# Compiling model...
# Model compiled!

# %%
# Setup callbacks
with strategy.scope():
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='val_mean_iou',
        mode='max',
        patience=30,
        restore_best_weights=True
    )
    
    viz_callback = VizCallback(X_val, y_val)

# %%
# Train the model
with strategy.scope():
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=[early_stopping, viz_callback],
        verbose=1,
        class_weight={0:1,1:1,2:1,3:1,4:100}
    ).history
    
    # Calculate and print the final validation accuracy
    final_val_meanIoU = round(max(history['val_mean_iou'])* 100, 2)
    print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')
# Out:
# Epoch 1/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - class1: 0.1106 - class2: 0.0645 - class3: 0.0316 - class4: 9.8832e-04 - loss: 175.9025 - mean_iou: 0.0457
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1734164290.540941      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 1 } dim { size: 64 } dim { size: 128 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 1 } dim { size: 64 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 64 } dim { size: 64 } dim { size: 128 } } }
# W0000 00:00:1734164290.542068      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 64 } dim { size: 64 } dim { size: 128 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 64 } dim { size: 64 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 64 } dim { size: 64 } dim { size: 128 } } }
# W0000 00:00:1734164290.542359      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 64 } dim { size: 32 } dim { size: 64 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 64 } dim { size: 128 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 128 } dim { size: 32 } dim { size: 64 } } }
# W0000 00:00:1734164290.542900      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 128 } dim { size: 32 } dim { size: 64 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 128 } dim { size: 128 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 128 } dim { size: 32 } dim { size: 64 } } }
# W0000 00:00:1734164290.543196      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 128 } dim { size: 16 } dim { size: 32 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 128 } dim { size: 256 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 256 } dim { size: 16 } dim { size: 32 } } }
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - class1: 0.1099 - class2: 0.0644 - class3: 0.0314 - class4: 9.9095e-04 - loss: 175.8810 - mean_iou: 0.0454 - val_class1: 0.0838 - val_class2: 0.1671 - val_class3: 0.0000e+00 - val_class4: 0.0018 - val_loss: 162.5466 - val_mean_iou: 0.0572
# Epoch 2/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - class1: 0
1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - class1: 0.8688 - class2: 0.8281 - class3: 0.8676 - class4: 0.2767 - loss: 168.5184 - mean_iou: 0.6699
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - class1: 0.8686 - class2: 0.8279 - class3: 0.8674 - class4: 0.2761 - loss: 168.5040 - mean_iou: 0.6696 - val_class1: 0.7241 - val_class2: 0.5874 - val_class3: 0.7019 - val_class4: 0.0962 - val_loss: 160.0032 - val_mean_iou: 0.4870
# Epoch 137/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - class1: 0.8617 - class2: 0.8216 - class3: 0.8619 - class4: 0.2650 - loss: 168.5660 - mean_iou: 0.6662 - val_class1: 0.7121 - val_class2: 0.5912 - val_class3: 0.7260 - val_class4: 0.1166 - val_loss: 158.8602 - val_mean_iou: 0.5055
# Epoch 138/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - class1: 0.8606 - class2: 0.8123 - class3: 0.8574 - class4: 0.1998 - loss: 168.5081 - mean_iou: 0.6434 - val_class1: 0.7145 - val_class2: 0.5338 - val_class3: 0.7191 - val_class4: 0.0147 - val_loss: 157.8717 - val_mean_iou: 0.4515
# Epoch 139/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - class1: 0.8317 - class2: 0.7694 - class3: 0.8267 - class4: 0.1469 - loss: 168.8544 - mean_iou: 0.5995 - val_class1: 0.7233 - val_class2: 0.5643 - val_class3: 0.6672 - val_class4: 0.1055 - val_loss: 159.7081 - val_mean_iou: 0.4936
# Epoch 140/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - class1: 0.8561 - class2: 0.8043 - class3: 0.8510 - class4: 0.1913 - loss: 168.6130 - mean_iou: 0.6349 - val_class1: 0.7145 - val_class2: 0.5937 - val_class3: 0.6618 - val_class4: 0.3314 - val_loss: 159.9925 - val_mean_iou: 0.5307
# Epoch 141/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - class1: 0.8195 - class2: 0.7545 - class3: 0.8097 - class4: 0.1464 - loss: 169.0601 - mean_iou: 0.5942
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - class1: 0.8196 - class2: 0.7548 - class3: 0.8099 - class4: 0.1467 - loss: 169.0532 - mean_iou: 0.5944 - val_class1: 0.7674 - val_class2: 0.5972 - val_class3: 0.7597 - val_class4: 0.2590 - val_loss: 158.5868 - val_mean_iou: 0.5648
# Epoch 142/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - class1: 0.8611 - class2: 0.8163 - class3: 0.8596 - class4: 0.2368 - loss: 168.5894 - mean_iou: 0.6556 - val_class1: 0.7568 - val_class2: 0.5385 - val_class3: 0.6915 - val_class4: 0.3147 - val_loss: 161.4315 - val_mean_iou: 0.5332
# Final validation Mean Intersection Over Union: 58.09%

# %%
# Plot and display training and validation loss
plt.figure(figsize=(18, 3))
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_loss'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Cross Entropy')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# Plot and display training and validation mean IoU
plt.figure(figsize=(18, 3))
plt.plot(history['mean_iou'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
plt.plot(history['val_mean_iou'], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
plt.title('Mean Intersection over Union')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model


def post_processing_network(input_shape, num_classes):
    
    inputs = layers.Input(shape=input_shape)

    # Encoder (contrazione)
    x1 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(inputs)
    x1 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(x1)
    p1 = layers.MaxPooling2D((2, 2))(x1)

    # Decoder (espansione)
    u1 = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(p1)
    u1 = layers.concatenate([u1, x1], axis=3)
    u1 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(u1)
    u1 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(u1)

    # Output
    output = layers.Conv2D(num_classes, (1, 1), activation="softmax")(u1)

    model = Model(inputs, output)
    
    return model
    
@tf.function
def loss_post_processing(y_true, y_pred):

    iou0 = iou_loss_for_class(y_true, y_pred, 0)
    iou1 = iou_loss_for_class(y_true, y_pred, 1)
    iou2 = iou_loss_for_class(y_true, y_pred, 2)
    iou3 = iou_loss_for_class(y_true, y_pred, 3)
    iou4 = iou_loss_for_class(y_true, y_pred, 4)
    
    return iou1 + iou2 + iou3 + 500*iou4
    
with strategy.scope():
    model_post_processing = post_processing_network((64, 128, NUM_CLASSES), NUM_CLASSES)
    model_post_processing.compile(
        loss=loss_post_processing,
        optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE),
        metrics=[MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0]),
            tf.keras.metrics.IoU(NUM_CLASSES, [0], name="class0", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [1], name="class1", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [2], name="class2", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [3], name="class3", sparse_y_true=False, sparse_y_pred=False),
            tf.keras.metrics.IoU(NUM_CLASSES, [4], name="class4", sparse_y_true=False, sparse_y_pred=False)
        ]
    )

# %%
model.save("/kaggle/working/transformer.keras")

# %%
# Funzione per creare un dataset di predizioni e label
def create_predicted_dataset(model, dataset, max_batch = 10):
    predictions = []
    labels = []

    i = 0
    for X_batch, y_batch in dataset:
        if (i > max_batch):
            break
        preds = model.predict(X_batch)  # Calcola le predizioni
        predictions.append(preds)
        labels.append(y_batch.numpy())  # Converte le etichette in NumPy per una gestione più facile
        i += 1
        
    # Concatenazione delle predizioni e delle etichette
    predictions = tf.concat(predictions, axis=0)
    labels = tf.concat(labels, axis=0)
    
    # Stampa delle forme
    print(f"Predictions shape: {predictions.shape}")
    print(f"Labels shape: {labels.shape}")

    # Creazione di un nuovo dataset (predizioni, etichette)
    new_dataset = tf.data.Dataset.from_tensor_slices((predictions, labels))

    dataset2 = new_dataset.map(
        lambda x, y: random_flip(x, y, seed=seed),  # Define random_flip for augmentation if necessary
        num_parallel_calls=tf.data.AUTOTUNE
    )
    dataset3 = new_dataset.map(
        lambda x, y: random_zoom(x, y, seed=seed),  # Define random_flip for augmentation if necessary
        num_parallel_calls=tf.data.AUTOTUNE
    )
    dataset4 = new_dataset.map(
        lambda x, y: random_flip_up_down(x, y, seed=seed),  # Define random_flip for augmentation if necessary
        num_parallel_calls=tf.data.AUTOTUNE
    )
        
    dataset = new_dataset.concatenate(dataset2)
    dataset = new_dataset.concatenate(dataset3)
    dataset = new_dataset.concatenate(dataset4)


    # Batch the data
    new_dataset = new_dataset.batch(16, drop_remainder=False)
    new_dataset = new_dataset.prefetch(tf.data.AUTOTUNE)
    
    return new_dataset

# Creazione dei nuovi dataset
train_pred_dataset = create_predicted_dataset(model, train_dataset)
val_pred_dataset = create_predicted_dataset(model, val_dataset)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predictions shape: (2816, 64, 128, 5)
# Labels shape: (2816, 64, 128, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Predictions shape: (275, 64, 128, 5)
# Labels shape: (275, 64, 128, 5)

# %%
print(preds_training.shape)
print(y_train.shape)
# Out:
# (32064, 64, 128, 5)
# (8016, 64, 128)

# %%
# Setup callbacks
with strategy.scope():
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='mean_iou',
        mode='max',
        patience=40,
        restore_best_weights=True
    )

# %%
# Train the model
with strategy.scope():
    history = model_post_processing.fit(
        val_pred_dataset,
        epochs=1000,
        #validation_data=val_pred_dataset,
        callbacks=[early_stopping],
        verbose=1,
        class_weight={0:1,1:1,2:1,3:1,4:100}
    ).history
    
    # Calculate and print the final validation accuracy
    final_val_meanIoU = round(max(history['mean_iou'])* 100, 2)
    print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')
# Out:
# Epoch 1/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step
1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - class0: 0.0000e+00 - class1: 0.7216 - class2: 0.5374 - class3: 0.6010 - class4: 0.0361 - loss: 510.3520 - mean_iou: 0.6110
# Epoch 26/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - class0: 0.0000e+00 - class1: 0.7171 - class2: 0.5461 - class3: 0.5932 - class4: 0.0382 - loss: 506.7017 - mean_iou: 0.6052
# Epoch 27/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - class0: 0.0000e+00 - class1: 0.7211 - class2: 0.5330 - class3: 0.6124 - class4: 0.0355 - loss: 507.6462 - mean_iou: 0.6072
# Epoch 28/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - class0: 0.0000e+00 - class1: 0.7256 - class2: 0.5504 - class3: 0.6124 - class4: 0.0296 - loss: 513.9860 - mean_iou: 0.6091
# Epoch 29/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - class0: 0.0000e+00 - class1: 0.7310 - class2: 0.5223 - class3: 0.6297 - class4: 0.0371 - loss: 511.9695 - mean_iou: 0.6138
# Epoch 30/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - class0: 0.0000e+00 - class1: 0.7350 - class2: 0.5357 - class3: 0.6228 - class4: 0.0321 - loss: 510.8970 - mean_iou: 0.6162
# Epoch 31/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - class0: 0.0000e+00 - class1: 0.7276 - class2: 0.5695 - class3: 0.6169 - class4: 0.0082 - loss: 511.3678 - mean_iou: 0.5920
# Epoch 32/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - class0: 0.0000e+00 - class1: 0.7227 - class2: 0.5380 - class3: 0.6173 - class4: 0.0283 - loss: 507.9454 - mean_iou: 0.5966
# Epoch 33/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - class0: 0.0000e+00 - class1: 0.7331 - class2: 0.5434 - class3: 0.6209 - class4: 0.0327 - loss: 506.8483 - mean_iou: 0.6125
# Epoch 34/1000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - class0: 0.0000e+00 - class1: 0.7223 - class2: 0.5431 - class3: 0.6177 - class4: 0.0322 - loss: 505.6463 - mean_iou: 0.6081
# Epoch 35/1000
# 13/18 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - class0: 0.0000e+00 - class1: 0.7356 - class2: 0.5556 - class3: 0.6168 - class4: 0.0113 - loss: 504.0569 - mean_iou: 0.6067
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[147], line 3
#       1 # Train the model
#       2 with strategy.scope():
# ----> 3     history = model_post_processing.fit(
#       4         val_pred_dataset,
#       5         epochs=1000,
#       6         #validation_data=val_pred_dataset,
#       7         callbacks=[early_stopping],
#       8         verbose=1,
#       9         class_weight={0:1,1:1,2:1,3:1,4:100}
#      10     ).history
#      12     # Calculate and print the final validation accuracy
#      13     final_val_meanIoU = round(max(history['mean_iou'])* 100, 2)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import numpy as np
import tensorflow as tf

def predict_with_threshold(y_pred, num_classes, thresholds):
    """
    Predice la classe di ogni pixel nel batch di immagini, tenendo conto delle soglie per ogni classe.

    Parameters:
        model (tf.keras.Model): Modello TensorFlow per fare le predizioni.
        x (np.array): Immagini di input (shape: batch_size, height, width, channels).
        num_classes (int): Numero di classi.
        thresholds (list): Lista di soglie per ogni classe.

    Returns:
        np.array: Maschera di predizione (shape: batch_size, height, width) con la classe predetta per ogni pixel.
    """
    batch_size, height, width, _ = y_pred.shape
    predicted_mask = np.zeros((batch_size, height, width), dtype=int)

    # Iteriamo sui pixel
    for b in range(batch_size):
        for i in range(height):
            for j in range(width):
                # Otteniamo le probabilità per tutte le classi per il pixel (i, j)
                probabilities = y_pred[b, i, j]
                
                # Ordiniamo le probabilità in ordine decrescente e otteniamo gli indici delle classi
                '''sorted_classes = np.argsort(probabilities)[::-1]  # Classi ordinate in base alla probabilità (decrescente)
                
                # Per ogni classe, verifica se la probabilità supera la soglia
                assigned_class = 0  # Classe di default (classe 0)
                for class_idx in sorted_classes:
                    if probabilities[class_idx] >= thresholds[class_idx]:
                        assigned_class = class_idx
                        break'''
                
                # Assegna il pixel alla classe trovata
                #predicted_mask[b, i, j] = assigned_class

    return predicted_mask


def calculate_miou_from_model_with_threshold(model, val_dataset, num_classes, thresholds):
    """
    Calcola la Mean Intersection over Union (mIoU) utilizzando una soglia specifica per ogni classe.

    Parameters:
        model (tf.keras.Model): Modello TensorFlow per fare le predizioni.
        val_dataset (tf.data.Dataset): Dataset di validazione (x, y), dove y è one-hot encoded.
        num_classes (int): Numero di classi.
        thresholds (list): Soglie per ogni classe.

    Returns:
        float: MIoU calcolata sulle classi.
    """
    intersection_sum = np.zeros(num_classes)
    union_sum = np.zeros(num_classes)

    y_pred = model.predict(val_dataset)  # y_pred shape (batch_size, height, width, num_classes)
    y_true = y_val

    y_pred_mask = predict_with_threshold(y_pred, num_classes, thresholds)  # Predizioni con soglie

    # Confrontiamo la predizione con la verità di terra
    for c in range(num_classes):
        pred_mask = (y_pred_mask == c)
        true_mask = (y_true == c)  # Verità di terra per la classe c

        intersection = np.logical_and(pred_mask, true_mask).sum()
        union = np.logical_or(pred_mask, true_mask).sum()

        intersection_sum[c] += intersection
        union_sum[c] += union

    # Calcola la IoU per ogni classe
    iou_per_class = [
        intersection_sum[c] / union_sum[c] if union_sum[c] != 0 else 1.0
        for c in range(num_classes)
    ]

    # Media delle IoU per tutte le classi
    miou = np.mean(iou_per_class)
    return miou


def find_optimal_threshold_for_class(model, val_dataset, num_classes, thresholds=np.arange(0.0, 0.9, 0.2)):
    """
    Trova la soglia ottimale per ogni classe che massimizza la Mean IoU (mIoU).

    Parameters:
        model (tf.keras.Model): Modello TensorFlow per fare le predizioni.
        val_dataset (tf.data.Dataset): Dataset di validazione (x, y), dove y è one-hot encoded.
        num_classes (int): Numero di classi.
        thresholds (array): Intervallo di soglie da testare.

    Returns:
        list: Una lista con la soglia ottimale per ciascuna classe.
    """
    optimal_thresholds = []

    # Per ciascuna classe, testiamo diverse soglie
    for class_idx in range(num_classes):
        class_idx=0
        best_miou = -1
        best_threshold = 0.0
        
        for threshold in thresholds:
            # Calcola la mIoU con la soglia corrente
            miou = calculate_miou_from_model_with_threshold(
                model, val_dataset, num_classes, thresholds=[threshold if i == class_idx else 0.0 for i in range(num_classes)])
            
            # Aggiorna la soglia se la mIoU è migliore
            if miou > best_miou:
                best_miou = miou
                best_threshold = threshold
    
                print(best_miou)
    
        # Salviamo la soglia ottimale per questa classe
        optimal_thresholds.append(best_threshold)

    return optimal_thresholds


# Esempio di utilizzo:
optimal_thresholds = find_optimal_threshold_for_class(model, val_dataset, NUM_CLASSES)

# Mostra la soglia ottimale per ogni classe
for i, threshold in enumerate(optimal_thresholds):
    print(f"Soglia ottimale per la classe {i}: {threshold:.2f}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# 0.049165974691242516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 0.049165974691242516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 0.049165974691242516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 0.049165974691242516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 0.049165974691242516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 126
#     122     return optimal_thresholds
#     125 # Esempio di utilizzo:
# --> 126 optimal_thresholds = find_optimal_threshold_for_class(model, val_dataset, NUM_CLASSES)
#     128 # Mostra la soglia ottimale per ogni classe
#     129 for i, threshold in enumerate(optimal_thresholds):
#
# Cell In[66], line 109, in find_optimal_threshold_for_class(model, val_dataset, num_classes, thresholds)
#     105 best_threshold = 0.0
#     107 for threshold in thresholds:
#     108     # Calcola la mIoU con la soglia corrente
# --> 109     miou = calculate_miou_from_model_with_threshold(
#     110         model, val_dataset, num_classes, thresholds=[threshold if i == class_idx else 0.0 for i in range(num_classes)])
#     112     # Aggiorna la soglia se la mIoU è migliore
#     113     if miou > best_miou:
#
# Cell In[66], line 59, in calculate_miou_from_model_with_threshold(model, val_dataset, num_classes, thresholds)
#      56 intersection_sum = np.zeros(num_classes)
#      57 union_sum = np.zeros(num_classes)
# ---> 59 y_pred = model.predict(val_dataset)  # y_pred shape (batch_size, height, width, num_classes)
#      60 y_true = y_val
#      62 y_pred_mask = predict_with_threshold(y_pred, num_classes, thresholds)  # Predizioni con soglie
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:504, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     502 callbacks.on_predict_batch_begin(step)
#     503 data = get_data(iterator)
# --> 504 batch_outputs = self.predict_function(data)
#     505 outputs = append_to_outputs(batch_outputs, outputs)
#     506 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save("/kaggle/working/keras.h5")

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_confusion_matrix(model, test_data, class_names):
    """
    Plots the confusion matrix for the given model and test data.
    
    Args:
        model: Trained Keras model.
        test_data: A `tf.data.Dataset` or similar iterable with (inputs, labels).
        class_names: List of class names corresponding to the labels.
    """
    # Get ground-truth labels and model predictions
    y_true = []
    y_pred = []
    
    for inputs, labels in test_data:
        predictions = model.predict(inputs)
        y_true.extend(np.argmax(labels.numpy(), axis=-1))
        y_pred.extend(np.argmax(predictions, axis=-1))

    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Plot the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model, val_dataset, [0,1,2,3,4])

# %%
model.evaluate(val_dataset)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - class1: 0.7117 - class2: 0.5795 - class3: 0.7381 - class4: 0.1002 - loss: nan - mean_iou: 0.4955
# [159.45480346679688,
#  0.5625826120376587,
#  0.7098696827888489,
#  0.6259270906448364,
#  0.6774324774742126,
#  0.3128204941749573]

# %%
X_val_pred = np.expand_dims(X_val, axis=3)

preds = model.predict(X_val_pred)
preds = np.argmax(preds, axis=-1)
print(f"Predictions shape: {preds.shape}")

# %%
background = 0
threshold_percentage = 70

# Itera su tutte le immagini e maschere
for i in range(len(preds)):
    
    if np.any(preds[i] == background):

        total_pixels = 64 * 128
        label_pixels = np.sum(preds[i] == background)
        label_percentage = (label_pixels / total_pixels) * 100

        #if ((label_percentage <= threshold_percentage)):
        new_label = cleaning_background(preds[i])
        preds[i] = new_label

# %%
y_true = []
y_pred = []


for i in range(len(preds)):
    y_true.extend(y_val[i])
    y_pred.extend(preds[i])

y_true = np.array(y_true).flatten()
y_pred = np.array(y_pred).flatten()

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1,2,3,4])
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title("Confusion Matrix")
plt.show()

# %%
preds = model.predict(X_test)
preds = np.argmax(preds, axis=-1)
print(f"Predictions shape: {preds.shape}")
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step
# Predictions shape: (10022, 64, 128)

# %%
preds = model.predict(X_test)
preds2 = model_post_processing.predict(preds)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step

# %%
preds = np.argmax(preds2, axis=-1)
print(f"Predictions shape: {preds.shape}")
# Out:
# Predictions shape: (10022, 64, 128)

# %%
background = 0
threshold_percentage = 60

# Itera su tutte le immagini e maschere
for i in range(len(preds)):
    
    if np.any(preds[i] == background):

        total_pixels = 64 * 128
        label_pixels = np.sum(preds[i] == background)
        label_percentage = (label_pixels / total_pixels) * 100
            
        #if ((label_percentage <= threshold_percentage)):
        new_label = cleaning_background(preds[i])
        preds[i] = new_label

# %%
import pandas as pd

def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
from time import time

# Create and download the csv submission file
timestep_str = int(time())
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)
